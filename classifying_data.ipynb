# %%
import pandas as pd
import pickle
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from app.model.pipeline import SongPipeline
from app.model.utils import clean

# %%
model = AutoModelForSequenceClassification.from_pretrained("./app/saved_model")
tokenizer = AutoTokenizer.from_pretrained("./app/saved_model")

# %%
pipe = SongPipeline(
            model=model,
            tokenizer=tokenizer,
            device=0, # gpu number, -1 if cpu used
            return_all_scores=True,
            function_to_apply='sigmoid'
        )

# %%
def top_k_emotions(data:list, threshold:float, k:int):
    texts = data['lyric']
    titles = data['title']
    singers = data['singer']
    urls = data['url']
    global error_idss 
    
    if not 0 <= threshold <=1:
        raise ValueError("theshold must be a float b/w 0 ~ 1.")
    results = {}
    for idx, text in enumerate(texts):
        try:
            cur_result = {}
            text = clean(text)
            for out in pipe(text, stride=128, return_overflowing_tokens=True,
                            padding=True, truncation=True)[0]:
                if out["score"] > threshold:
                    cur_result[out["label"]] = round(out["score"], 2)
            cur_result = sorted(cur_result.items(), key=lambda x: x[1], reverse=True)
            preview = text[:50] + "..."
            results[titles[idx]] = (cur_result[:k], singers[idx], urls[idx], preview)
        except:
            error_idss.append(idx)
        
    return results

# %%
import os
from collections import defaultdict
songs_database = defaultdict(list)
error_idss = []

for filename in os.listdir("data"):
    file = pd.read_csv(os.path.join("./data", filename))
    result = top_k_emotions(data=file, threshold=0.0, k=5)
    for title, content in result.items():
        feelings, singer, url, preview = content
        if feelings[0][0] != '없음':
            feeling = feelings[0][0]
        else:
            feeling = feelings[1][0]
        songs_database[feeling].append((title, singer, url, preview))
# Out:
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /opt/ml/final_project/develop/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
error_idss
# Out:
# [49, 35, 49, 4, 17, 37, 49]

# %%
songs_database.keys()
# Out:
# dict_keys(['즐거움/신남', '슬픔', '행복', '아껴주는', '기대감', '안타까움/실망', '기쁨', '짜증', '깨달음', '힘듦/지침', '비장함', '고마움', '화남/분노', '당황/난처', '불안/걱정', '감동/감탄', '흐뭇함(귀여움/예쁨)'])

# %%
with open('./songs_database.pkl', 'wb') as f:
    pickle.dump(songs_database, f)

# %%
with open('./songs_database.pkl', 'rb') as f:
    d = pickle.load(f)

# %%
d
# Out:
# defaultdict(list,
#             {'즐거움/신남': [('강남스타일',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=3853978',
#                '오빤 강남스타일 강남스타일 낮에는 따사로운 인간적인 여자 커피 한잔의 여유를 아는 품격 있...'),
#               ('크레용 (Crayon)',
#                'G-DRAGON',
#                'https://www.melon.com/song/detail.htm?songId=3906377',
#                '크레용 (Crayon) GET YOUR CRAYON GET YOUR CRAYON 머리 어깨...'),
#               ('립스틱 (LIPSTICK)',
#                '오렌지 캬라멜',
#                'https://www.melon.com/song/detail.htm?songId=3903316',
#                '립스틱 스틱 세우고 립스틱 스틱 세우고 어찌나 눈이 높던지 애인이 있는 건지 살짝 시크해보...'),
#               ('너는 나 나는 너',
#                '지코 (ZICO)',
#                'https://www.melon.com/song/detail.htm?songId=8028724',
#                '넌 나고 난 너야 난 너고 넌 나야 마음이 같다면 둘은 서로가 될 거야 넌 나고 난 너야 ...'),
#               ('러시안 룰렛 (Russian Roulette)',
#                'Red Velvet (레드벨벳)',
#                'https://www.melon.com/song/detail.htm?songId=9634954',
#                'La La La La La La La La La La La La La La La La La...'),
#               ('puzzle',
#                'C JAMM, BewhY (비와이)',
#                'https://www.melon.com/song/detail.htm?songId=8308231',
#                'I ll Take 1 I ll take 2 이젠 대한민국의 Main deux 나보다 바쁜 ...'),
#               ('That That (prod. & feat. SUGA of BTS)',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=34997078',
#                '20 22 PSY Coming back (이리 오너라) Long time no see hu...'),
#               ('ZOOM',
#                '제시 (Jessi)',
#                'https://www.melon.com/song/detail.htm?songId=34883833',
#                'Lights Camera Action I see you lookin at my P I C ...'),
#               ('Celeb',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=34997079',
#                'You so popular be ma formula May I call you a cele...'),
#               ('Real Love',
#                '오마이걸 (OH MY GIRL)',
#                'https://www.melon.com/song/detail.htm?songId=34808386',
#                '우린 이 음악을 빌려 이 분위기를 빌려 지금 이 공기 이건 마치 7시간 비행 뒤 만난 것 ...'),
#               ('바람났어 (Feat. 박봄)',
#                'GG (박명수 & G-Dragon)',
#                'https://www.melon.com/song/detail.htm?songId=3467463',
#                'Oh G-Dragon A-yo Great Park 뭐해요 딱히 오늘 파티있는데 같이 갈래요...'),
#               ('Hot Summer',
#                'f(x)',
#                'https://www.melon.com/song/detail.htm?songId=3440448',
#                'Hot Hot Hot Hot Summer Hot Hot Hot Hot Hot Hot Hot...'),
#               ('Oh Yeah (Feat. 박봄)',
#                'GD&TOP',
#                'https://www.melon.com/song/detail.htm?songId=3065250',
#                'oh yeah oh oh yeah top oh yeah oh oh yeah gd oh ye...'),
#               ('High High',
#                'GD&TOP',
#                'https://www.melon.com/song/detail.htm?songId=3065249',
#                "선수입장 알아서 모셔 T O P class i'm mr G in the club in my..."),
#               ('뿜뿜',
#                '모모랜드 (MOMOLAND)',
#                'https://www.melon.com/song/detail.htm?songId=30816860',
#                '설레어 너와 나의 랑데뷰 랑데뷰 내 마음을 들었다 놨다 해 맘대루 맘대루 지금 내 눈엔 눈...'),
#               ('Bad Boy',
#                'Red Velvet (레드벨벳)',
#                'https://www.melon.com/song/detail.htm?songId=30864993',
#                'Who dat who dat who dat boy 수많은 사람 속 눈에 띈 무심한 그 표정...'),
#               ('That That (prod. & feat. SUGA of BTS)',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=34997078',
#                '20 22 PSY Coming back (이리 오너라) Long time no see hu...'),
#               ('ZOOM',
#                '제시 (Jessi)',
#                'https://www.melon.com/song/detail.htm?songId=34883833',
#                'Lights Camera Action I see you lookin at my P I C ...'),
#               ('Celeb',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=34997079',
#                'You so popular be ma formula May I call you a cele...'),
#               ('Real Love',
#                '오마이걸 (OH MY GIRL)',
#                'https://www.melon.com/song/detail.htm?songId=34808386',
#                '우린 이 음악을 빌려 이 분위기를 빌려 지금 이 공기 이건 마치 7시간 비행 뒤 만난 것 ...'),
#               ('SHAKE IT',
#                '씨스타',
#                'https://www.melon.com/song/detail.htm?songId=5748499',
#                '너만을 유혹하는 춤 우우우 우우 심장에 매력 발산 중 우우우 우우 손끝만 스쳐도 막 쿵쿵 ...'),
#               ('음오아예 (Um Oh Ah Yeh)',
#                '마마무 (Mamamoo)',
#                'https://www.melon.com/song/detail.htm?songId=5743804',
#                'oh yes 음 오 아 예 너에게 빠져들겠어 자꾸 반응하잖아 oh yes 음 오 아 예 그...'),
#               ('Oasis (Feat. ZICO)',
#                'Crush',
#                'https://www.melon.com/song/detail.htm?songId=5771304',
#                '난 널 you 목말라해 너무 더워 물이 필요해 Hot in here 난 웅덩이 깊이 파인 ...'),
#               ('Psycho',
#                'Red Velvet (레드벨벳)',
#                'https://www.melon.com/song/detail.htm?songId=32273582',
#                'Psycho 널 어쩌면 좋을까 이런 맘은 또 첨이라 Up & Down이 좀 심해 조절이 자...'),
#               ('HIP',
#                '마마무 (Mamamoo)',
#                'https://www.melon.com/song/detail.htm?songId=32175937',
#                'All I wanna be is 멋짐 내 마음대로 골라 kick it 머리 어깨 무릎 다 ...'),
#               ('까탈레나 (Catallena)',
#                '오렌지 캬라멜',
#                'https://www.melon.com/song/detail.htm?songId=4503810',
#                '춤추는 작은 까탈레나 Red Sun 나도 모르게 빠져 들어가 도도한 콧대 까탈레나 Red ...'),
#               ('빠빠빠',
#                '크레용팝',
#                'https://www.melon.com/song/detail.htm?songId=4148967',
#                '다같이 원 빠빠 빠빠 날따라 투 빠빠 빠빠 소리쳐 호 호 뛰어봐 쿵 쿵 날따라 해해 엄마도...'),
#               ('New Face',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=30403590',
#                '어딜 쳐다보는 거냐고 솔직히 너 그래 너 생판 처음 만난 너 왜 널 쳐다보는 거냐고 궁금해...'),
#               ('IDOL',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=31266290',
#                'You can call me artist You can call me idol 아님 어떤 ...')],
#              '슬픔': [('나혼자 (Alone)',
#                '씨스타',
#                'https://www.melon.com/song/detail.htm?songId=3763493',
#                "Whoo Whoo Whoo Whoo I don't wanna cry Whoo Whoo Wh..."),
#               ('I Love You',
#                '2NE1',
#                'https://www.melon.com/song/detail.htm?songId=3847197',
#                '그대 나에게만 잘해줘요 항상 나에게만 웃어줘요 I said Ooh 질투하게 하지 마요 Oo...'),
#               ('정말로 사랑한다면',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3832101',
#                '사랑한단 말로는 사랑할 순 없군요 그대 상처 주네요 나의 뻔한 그 말이 너무 쉽게 뱉은 말...'),
#               ('첫사랑',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3753302',
#                '처음 널 봤을 때 왠지 다른 느낌 너와 함께 말하고 싶어 웃을 때마다 이 마음을 알아가 이...'),
#               ('Lovey-Dovey',
#                '티아라',
#                'https://www.melon.com/song/detail.htm?songId=3663978',
#                '너무 뻔해 나는 오늘도 혼자서 아 심심해 결국 이렇게 하루가 우우 우우 지나가겠지 봐봐 지...'),
#               ('나를 사랑했던 사람아',
#                '허각',
#                'https://www.melon.com/song/detail.htm?songId=3758104',
#                '잘 지내고 있는건지 무슨 일 없는지 지겹던 너의 잔소리가 너무 그리워서 그렇게 나 하나밖에...'),
#               ('MONSTER',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=3818487',
#                '오랜만이야 못 본 사이 그댄 얼굴이 좋아 보여 예뻐졌다 넌 항상 내 눈엔 원래 고와 보여 ...'),
#               ('BLUE',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=3715672',
#                '겨울이 가고 봄이 찾아오죠 우린 시들고 그리움 속에 맘이 멍들었죠 I m singing m...'),
#               ('목소리 (Feat. 개리 Of 리쌍)',
#                '백지영',
#                'https://www.melon.com/song/detail.htm?songId=3791867',
#                '니 목소리가 들려 니 목소리가 들려 니 목소리가 들려 내 귓가에 파도소리 아무도 없는 것 ...'),
#               ("이러지마 제발 (Please Don't...)",
#                '케이윌',
#                'https://www.melon.com/song/detail.htm?songId=3922071',
#                '나란히 앉은 자동차 속에선 음악도 흐르지 않아 늘 잡고 있던 니 왼손으로 너 입술만 뜯고 ...'),
#               ('보여줄게',
#                '에일리(Ailee)',
#                'https://www.melon.com/song/detail.htm?songId=3929469',
#                '내가 사준 옷을 걸치고 내가 사준 향술 뿌리고 지금쯤 넌 그녈 만나 또 웃고 있겠지 그렇게...'),
#               ('먼지가 되어',
#                '로이킴, 정준영',
#                'https://www.melon.com/song/detail.htm?songId=3928293',
#                '바하의 선율에 젖은 날에는 잊었던 기억들이 피어나네요 바람에 날려간 나의 노래도 휘파람 소...'),
#               ('DAY BY DAY',
#                '티아라',
#                'https://www.melon.com/song/detail.htm?songId=3840800',
#                '내품은 너에게 피난처 다른 사람에 나는 버려져 사랑 그 끝은 까만 터널속 보이지 않는 길이...'),
#               ('애상',
#                '10CM',
#                'https://www.melon.com/song/detail.htm?songId=3666573',
#                '말리지마 내 이런 사랑을 너만 보면 미칠 것 같은 이 맘을 누가 알겠어 웨딩드레스 입은 니...'),
#               ('어땠을까 (Feat. 박정현)',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=3853980',
#                '내가 그때 널 잡았더라면 너와 나 지금보다 행복했을까 마지막에 널 안아줬다면 어땠을까 나의...'),
#               ('뜨거운 안녕 (Feat. 성시경)',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=3853977',
#                'PSY collaboration TOY introducing 성발라 불타 올랐던 남과 여 ...'),
#               ('그댈 마주하는건 힘들어 (그마힘)',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3832098',
#                '그댈 마주하는거는 너무 힘들어 그때 그 기억이 나를 괴롭게 하네 이런 말을 해도 될진 모르...'),
#               ('Officially Missing You, Too',
#                '긱스 (Geeks), 소유 (SOYOU)',
#                'https://www.melon.com/song/detail.htm?songId=3946867',
#                '애써 너에게 건냈던 말 good bye 이젠 혼자 남게된 이 밤 without you 난 ...'),
#               ('꽃송이가',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3753309',
#                '배드민턴 치자고 꼬셔 커피 한 잔 하자고 불러 동네 한 번 걷자고 꼬셔 넌 한 번도 그래 ...'),
#               ('Only One',
#                '보아 (BoA)',
#                'https://www.melon.com/song/detail.htm?songId=3859894',
#                '멀어져만 가는 그대 You re the only one 내가 사랑했던 것만큼 You re ...'),
#               ('거기서거기 (Without You)',
#                '다이나믹 듀오',
#                'https://www.melon.com/song/detail.htm?songId=3665143',
#                '재미난 영화를 봐도 다 거기서 거기 여행을 가도 다 거기서 거기 새로운 음악도 다 거기서 ...'),
#               ('Missing You (Feat. 김윤아 Of 자우림)',
#                'G-DRAGON',
#                'https://www.melon.com/song/detail.htm?songId=3906383',
#                'Yeah 아무 생각 없이 평소와 같이 보통 사람들과 만나 웃고 말하지 밤이 되면 TV가 내...'),
#               ('춥다 (Feat. 이하이)',
#                '에픽하이 (EPIK HIGH)',
#                'https://www.melon.com/song/detail.htm?songId=3922586',
#                '봄이 와 꽃을 피우고 여름이 와 기억이 녹아 내려도 난 원래 사계절이 어울리지 않아 차가운...'),
#               ('Touch',
#                '미쓰에이',
#                'https://www.melon.com/song/detail.htm?songId=3713013',
#                '닫힌 내 가슴은 누구도 사랑할 수가 없다 그렇게 믿었는데 어느새 내 가슴이 열리고 있어 굳...'),
#               ('너도 나처럼',
#                '2am',
#                'https://www.melon.com/song/detail.htm?songId=3731994',
#                '하루종일 니 생각만 하다가 한 가닥 눈물이 멋대로 주르륵 흐른다 걸음걸음 니 모습이 밟혀서...'),
#               ('Volume Up',
#                '4minute',
#                'https://www.melon.com/song/detail.htm?songId=3764899',
#                '나를 처음 봤을 땐 눈도 못 땠었던 너 uh uh uh uh 너 uh uh uh uh 쉽다...'),
#               ('어디에도',
#                '엠씨더맥스 (M.C the MAX)',
#                'https://www.melon.com/song/detail.htm?songId=8033528',
#                '차가워진 눈빛을 바라보며 이별의 말을 전해 들어요 아무 의미 없던 노래 가사가 아프게 귓가...'),
#               ('널 사랑하지 않아',
#                '어반자카파',
#                'https://www.melon.com/song/detail.htm?songId=8199190',
#                '무슨 말을 할까 어디서부터 어떻게 고개만 떨구는 나 그런 날 바라보는 너 그 어색한 침묵 ...'),
#               ('이 사랑',
#                '다비치',
#                'https://www.melon.com/song/detail.htm?songId=8071102',
#                '시간을 되돌리면 기억도 지워질까 해볼 수도 없는 말들을 내뱉는 걸 알아 널 힘들게 했고 눈...'),
#               ('이 소설의 끝을 다시 써보려 해',
#                '한동근',
#                'https://www.melon.com/song/detail.htm?songId=5398990',
#                '시계가 반대로 돌아가고 있어 TV속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 있어 잊...'),
#               ('내가 저지른 사랑',
#                '임창정',
#                'https://www.melon.com/song/detail.htm?songId=9631530',
#                '떠나거든 내 소식이 들려오면 이제는 모른다고 해줘 언제나 내 맘속에서 커져만 갔던 너를 조...'),
#               ('D (half moon) (Feat. 개코)',
#                'DEAN',
#                'https://www.melon.com/song/detail.htm?songId=8109412',
#                'Love love the stars Love love the moon 별 다를 것 없이 똑...'),
#               ('Why So Lonely',
#                '원더걸스',
#                'https://www.melon.com/song/detail.htm?songId=8254545',
#                '너와 입술이 닿을 때부터 모든 게 달라질 줄 알았는데 별거 없어 넌 다른 게 없어 너와 보...'),
#               ('돌아오지마 (Feat. 용준형 Of 비스트)',
#                '헤이즈 (Heize)',
#                'https://www.melon.com/song/detail.htm?songId=8143111',
#                '아직도 비가 내리면 빗 소릴 beat 삼아 너를 끄적이곤 해 괜찮지 않아 난 내일도 알람이...'),
#               ('Rain',
#                '태연 (TAEYEON)',
#                'https://www.melon.com/song/detail.htm?songId=8042553',
#                '텅 빈 회색 빛 거린 참 허전해 쓸쓸한 기분에 유리창을 열어 내민 두 손 위로 떨어진 빗방...'),
#               ('TT',
#                'TWICE (트와이스)',
#                'https://www.melon.com/song/detail.htm?songId=30054344',
#                '이러지도 못하는데 저러지도 못하네 그저 바라보며 ba-ba-ba-baby 매일 상상만 해 ...'),
#               ('쏘쏘',
#                '백아연',
#                'https://www.melon.com/song/detail.htm?songId=8189661',
#                '눈이 높은 건 절대 아닌데 딱히 맘이 끌리지가 않아 한두 번 만나보고 며칠을 연락해도 어색...'),
#               ('다시 너를',
#                '매드클라운, 김나영',
#                'https://www.melon.com/song/detail.htm?songId=8100402',
#                '다시 너를 볼 수 있을까 다시 스쳐 지나가 버린 운명 앞에 서 있어 깨지 못할 꿈이었을까 ...'),
#               ('너였다면',
#                '정승환',
#                'https://www.melon.com/song/detail.htm?songId=8203900',
#                '왜 너에겐 그렇게 어려운지 애를 쓰는 나를 제대로 봐주는 게 너 하나에 이토록 아플 수 있...'),
#               ('꿈처럼',
#                '벤',
#                'https://www.melon.com/song/detail.htm?songId=8174429',
#                '나만 홀로 느낀 황홀함일까 그저 바라보는 시선이 무거워 맴도는 발걸음 여전히 네가 보고 싶...'),
#               ('안아줘',
#                '정준일',
#                'https://www.melon.com/song/detail.htm?songId=3620493',
#                '서러운 맘을 못 이겨 잠 못 들던 어둔 밤을 또 견디고 내 절망관 상관없이 무심하게도 아침...'),
#               ('I Like That',
#                '씨스타',
#                'https://www.melon.com/song/detail.htm?songId=8236055',
#                '남자는 똑같다는 게 그 말이 이제 이해돼 감이 오질 않아 너란 놈 이젠 있다 없다 왔다 갔...'),
#               ('숨',
#                '박효신',
#                'https://www.melon.com/song/detail.htm?songId=30011624',
#                '오늘 하루 쉴 숨이 오늘 하루 쉴 곳이 오늘만큼 이렇게 또 한번 살아가 침대 밑에 놓아둔 ...'),
#               ('스토커',
#                '10CM',
#                'https://www.melon.com/song/detail.htm?songId=5466962',
#                '나도 알아 나의 문제가 무엇인지 난 못났고 별 볼 일 없지 그 애가 나를 부끄러워 한다는 ...'),
#               ('봄여름가을겨울 (Still Life)',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=34845949',
#                '이듬해 질 녘 꽃 피는 봄 한여름 밤의 꿈 가을 타 겨울 내릴 눈 1년 네 번 또다시 봄 ...'),
#               ('사랑은 늘 도망가',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=34061322',
#                '눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만 떨었지...'),
#               ('정이라고 하자 (Feat. 10CM)',
#                'BIG Naughty (서동현)',
#                'https://www.melon.com/song/detail.htm?songId=34927767',
#                'Back to the day 갓 10대가 됐을 때 그때 내가 널 보지 못했다면 어땠을까 해...'),
#               ('LOVE me',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34875621',
#                'Hey girl, Where you at? (Where you at?) 대체 어디서 뭐 하...'),
#               ('다시 만날 수 있을까',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008524',
#                '너를 위해 해 줄 것이 하나 없어서 보낼 수밖에 없었고 네가 없이 사는 법을 알지 못해서 ...'),
#               ('INVU',
#                '태연 (TAEYEON)',
#                'https://www.melon.com/song/detail.htm?songId=34626109',
#                'Falling in love 너에겐 난 Option 시작부터 다른 너와 나 깨지는 Hear...'),
#               ('신호등',
#                '이무진',
#                'https://www.melon.com/song/detail.htm?songId=33480898',
#                '이제야 목적지를 정했지만 가려한 날 막아서네 난 갈 길이 먼데 새빨간 얼굴로 화를 냈던 친...'),
#               ('듣고 싶을까',
#                'MSG워너비(M.O.M)',
#                'https://www.melon.com/song/detail.htm?songId=34701627',
#                '우리 함께 듣던 그 노랠 듣고 싶을까 듣고 나서 잠시 날 생각은 할까 아주 혹시라도 넌 내...'),
#               ('아버지',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008527',
#                '하얀 머리 뽑아 달라며 한 개 백 원이라던 그 시절 다 지나가고 이젠 흰 눈만 남았네 그렇...'),
#               ('A bientot',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008528',
#                'A bientot A bientot 이 밤이 지나면 괜찮아질 수 있을까 쓰린 내 맘이 회복...'),
#               ('인생찬가',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008534',
#                '꿈처럼 지나간 시간 나는 무얼 찾고 싶었나 지도도 없이 걸어온 삶을 후회하진 않으리 떠난 ...'),
#               ('사랑역',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008529',
#                '돌고 돌아 사랑역 다시 한번 내렸네 아픔만 두고 떠나가는 저 기차는 말이 없는데 이리 갈까...'),
#               ('회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)',
#                'sokodomo',
#                'https://www.melon.com/song/detail.htm?songId=34256568',
#                '내가 슬플 때마다 이 노래가 찾아와 세상이 둥근 것처럼 우린 동글동글 인생은 회전목마 우린...'),
#               ('드라마',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=34481680',
#                '나도 한때는 그이의 손을 잡고 내가 온 세상 주인공이 된 듯 꽃송이의 꽃잎 하나하나까지 모...'),
#               ('리무진 (Feat. MINO) (Prod. GRAY)',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34298499',
#                '까만 리무진 보며 꿈을 키웠지 언젠가는 나도 저걸 갖게 될 거야 커다란 리무진에서 내가 내...'),
#               ('내 손을 잡아',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=3414749',
#                '느낌이 오잖아 떨리고 있잖아 언제까지 눈치만 볼 거니 네 맘을 말해봐 딴청 피우지 말란 말...'),
#               ('아무래도 난',
#                '주시크 (Joosiq)',
#                'https://www.melon.com/song/detail.htm?songId=34817660',
#                '아무렇지 않게 내 하루가 또 지나갈 쯤에 문득 네가 없다는 게 익숙해진 내가 낯설어지곤 해...'),
#               ('스물다섯, 스물하나',
#                '자우림',
#                'https://www.melon.com/song/detail.htm?songId=4276080',
#                '바람에 날려 꽃이 지는 계절엔 아직도 너의 손을 잡은 듯 그런 듯 해 그때는 아직 꽃이 아...'),
#               ('바라만 본다',
#                'MSG워너비(M.O.M)',
#                'https://www.melon.com/song/detail.htm?songId=33625988',
#                '내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁을 지켜...'),
#               ('눈이 오잖아(Feat.헤이즈)',
#                '이무진',
#                'https://www.melon.com/song/detail.htm?songId=34360855',
#                '한 달 좀 덜 된 기억들 주머니에 넣은 채 걷고 있어 몇 시간을 혹시 몰라 네가 좋아했던 ...'),
#               ('Counting Stars (Feat. Beenzino)',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34398735',
#                'Counting stars 밤하늘에 펄 Better than your LV Your LV ...'),
#               ('호랑수월가',
#                '탑현',
#                'https://www.melon.com/song/detail.htm?songId=34535898',
#                '흐르는 저 하늘을 물어 채는 범처럼 태산에 날아들어 숨어드는 새처럼 동산을 뛰고 뛰어가는 ...'),
#               ('고백',
#                '멜로망스',
#                'https://www.melon.com/song/detail.htm?songId=33868791',
#                '달이 차고 내 마음도 차고 이대로 담아 두기엔 너무 안타까워 너를 향해 가는데 달은 내게 ...'),
#               ('사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)',
#                '호미들',
#                'https://www.melon.com/song/detail.htm?songId=33359725',
#                '울려댔어 사이렌 텅 빈 길거리엔 도망치다 흘린 칼자루와 피가 흥건해 우리 그때 어릴땐 뭘 ...'),
#               ('봄날',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30244931',
#                '보고 싶다 이렇게 말하니까 더 보고 싶다 너희 사진을 보고 있어도 보고 싶다 너무 야속한 ...'),
#               ('미친 것처럼',
#                'V.O.S',
#                'https://www.melon.com/song/detail.htm?songId=35126568',
#                '너는 참 못됐다 나 없이도 잘 지내더라 언제쯤 나도 널 잊을 수 있을까 눈을 감아도 눈물이...'),
#               ('헤픈 우연',
#                '헤이즈 (Heize)',
#                'https://www.melon.com/song/detail.htm?songId=33503722',
#                '처음이라기엔 너무 길을 이미 다 아는 듯이 우연히라기엔 모두 다 정해진 듯이 우연히 눈을 ...'),
#               ('어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#                'AKMU (악뮤)',
#                'https://www.melon.com/song/detail.htm?songId=32061975',
#                '일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 ...'),
#               ('Shadow',
#                '세븐틴',
#                'https://www.melon.com/song/detail.htm?songId=35223433',
#                '저 멀리 뜨거운 해 떠오르지 않길 원했어 (Oh wuh) 빛의 반대편 그늘진 모든 게 싫어...'),
#               ('너, 너 (N번째 연애 X 휘인 (Whee In))',
#                '휘인 (Whee In)',
#                'https://www.melon.com/song/detail.htm?songId=34632789',
#                '하루 종일 집에 누워서 전화기만 보고 있잖아 내 머릿속은 네 생각들로만 짜여져 있어 날 찾...'),
#               ('서랍',
#                '10CM',
#                'https://www.melon.com/song/detail.htm?songId=34373632',
#                '어린 햇살 아래서 뛰어놀곤 했었던 가쁜 숨결 굽이진 골목 지나 길을 따라가보면 같은 기억 ...'),
#               ('어제처럼',
#                '폴킴',
#                'https://www.melon.com/song/detail.htm?songId=34701996',
#                'Trust the warmth inside Can you feel my love alive...'),
#               ('비가 오는 날엔',
#                '비스트',
#                'https://www.melon.com/song/detail.htm?songId=3397448',
#                '세상이 어두워지고 조용히 비가 내리면 여전히 그대로 오늘도 어김없이 난 벗어나질 못하네 너...'),
#               ('UGLY',
#                '2NE1',
#                'https://www.melon.com/song/detail.htm?songId=3509751',
#                '밝게 웃어보지만 내 맘에 들지 않아 난 예쁘지 않아 아름답지 않아 Oh oh oh oh O...'),
#               ('안녕이라고 말하지마',
#                '다비치',
#                'https://www.melon.com/song/detail.htm?songId=3536905',
#                '떨리는 너의 입술을 난 난 처음 보았지 무슨 말 하려고 말 하려고 뜸만 들이는지 슬픈 예감...'),
#               ('그리워 그리워',
#                '노을',
#                'https://www.melon.com/song/detail.htm?songId=3585793',
#                '늦은저녁 하루를보내고 찬바람에 창문을 닫으니 아득하게 조용한 방에서 아주 작은 조명하나를 ...'),
#               ('Hello',
#                '허각',
#                'https://www.melon.com/song/detail.htm?songId=3549031',
#                '우리 헤어지면 안되잖아 우리 이별하긴 이르잖아 이렇게 날 떠나가면 안돼요 내가 하지 못한 ...'),
#               ('Lonely',
#                '2NE1',
#                'https://www.melon.com/song/detail.htm?songId=3397797',
#                '지금 내가 하는 얘기 널 아프게 할지 몰라 아마 날 죽도록 미워하게 될 꺼야 내가 예전 같...'),
#               ('끝사랑',
#                '김범수',
#                'https://www.melon.com/song/detail.htm?songId=3436083',
#                '내가 이렇게 아픈데 그댄 어떨까요 원래 떠나는 사람이 더 힘든 법인데 아무 말하지 말아요 ...'),
#               ('서쪽 하늘',
#                '울랄라세션',
#                'https://www.melon.com/song/detail.htm?songId=3593455',
#                '서쪽하늘로 노을은 지고 이젠 슬픔이 돼버린 그대를 다시 부를수 없을 것 같아 또 한번 불러...'),
#               ('동경소녀',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3565240',
#                '오랜만이야 정말 보고 싶었지만 내 하찮은 자존심이 허락안했어 헤어진후에 많이 달라진것같아 ...'),
#               ('Fiction',
#                '비스트',
#                'https://www.melon.com/song/detail.htm?songId=3403761',
#                '아직 난 널 잊지 못하고 모든걸 다 믿지 못하고 이렇게 널 보내지 못하고 오늘도 다시 만들...'),
#               ('제발',
#                '김범수',
#                'https://www.melon.com/song/detail.htm?songId=3337773',
#                '잊지 못해 너를 있잖아 아직도 눈물 흘리며 널 생각해 늘 참지 못하고 투정 부린 것 미안해...'),
#               ("Don't Cry",
#                '박봄 (Park Bom)',
#                'https://www.melon.com/song/detail.htm?songId=3373007',
#                '사랑은 너무 쉽게 변해만 갔죠 서로 욕심 속에 아픈 상처만 남아 GOTTA LET YOU ...'),
#               ('회상 (Feat. 백지영)',
#                '리쌍',
#                'https://www.melon.com/song/detail.htm?songId=3534943',
#                '울 엄마가 나를 뱄을 때 앉아서 잠을 잤대 내 발길질 땜에 그렇게 난 뱃속에서부터 말썽을 ...'),
#               ('Cry Cry',
#                '티아라',
#                'https://www.melon.com/song/detail.htm?songId=3607859',
#                'Hey T-ARA 새빨간 장미처럼 가시같은 말로 날 찌른 너 Uh Uh Uh 넌 마치 문신...'),
#               ('TONIGHT',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=3156950',
#                'Tonight such a beautiful night sing with me now 20...'),
#               ('Ma Boy (마보이)',
#                '씨스타19',
#                'https://www.melon.com/song/detail.htm?songId=3385548',
#                "Let's go S.I.S.T.A.R, Sistar Baby stop breakin' my..."),
#               ('나만 몰랐던 이야기',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=3143550',
#                '정말 넌 다 잊었더라 반갑게 날 보는 너의 얼굴 보니 그제야 어렴풋이 아파오더라 새 살 차...'),
#               ('여우야',
#                '투개월',
#                'https://www.melon.com/song/detail.htm?songId=3565243',
#                '창 밖엔 서글픈 비만 내려오네 내 마음 너무 안타까워 이제 다시 볼 수가 없기에 처음 만났...'),
#               ('반짝반짝',
#                '걸스데이',
#                'https://www.melon.com/song/detail.htm?songId=3319849',
#                'Girls Day Do you hear me Listen 내 말을 좀 들어봐 오빤 정말 나...'),
#               ('사랑은 Move',
#                '시크릿',
#                'https://www.melon.com/song/detail.htm?songId=3573326',
#                'Come On Come On Come On Come On Come On Come On Co...'),
#               ('내꺼중에 최고',
#                '이현',
#                'https://www.melon.com/song/detail.htm?songId=3138749',
#                '넌 내꺼중에 최고 내 삶의 모든 것 중에 최고 눈이 멀었었나봐 미쳤나봐 왜 너를 못 알아봐...'),
#               ('달의 몰락',
#                '울랄라세션',
#                'https://www.melon.com/song/detail.htm?songId=3565242',
#                '나를 처음 만났을 때도 그녀는 나에게 말했지 탐스럽고 이쁜 저 이쁜 달 나랑 매일 만날 때...'),
#               ('죽고 싶단 말 밖에',
#                '허각',
#                'https://www.melon.com/song/detail.htm?songId=3602154',
#                '이렇게 너를 난 떠올리곤 해 길었던 순간들도 기억해 오늘도 너의 뒷모습을 잠시라도 볼 수 ...'),
#               ('연애시대 (Feat. Ra.D) (Narr. 한효주)',
#                '이승기',
#                'https://www.melon.com/song/detail.htm?songId=3573175',
#                '언제나 거침없던 내가 조금씩 눈치를 보고 있어 겉으론 관심 없는 척 차가운 도시의 남자인 ...'),
#               ('미친거니 (Feat. 방용국)',
#                '송지은',
#                'https://www.melon.com/song/detail.htm?songId=3164048',
#                '사랑이 아냐 이건 사랑이 아냐 너의 집착일 뿐이야 어디 있든지 내가 무얼 하든지 무서워 나...'),
#               ('그 남자 그 여자',
#                '포맨 (4MEN), 미(MIIII)',
#                'https://www.melon.com/song/detail.htm?songId=3590149',
#                '밥을 먹어도 혼자 야구를 봐도 혼자 거리를 걸어도 나 혼자 혼자이기 싫은데 또 방에 누워도...'),
#               ('사랑 사랑아',
#                '다비치',
#                'https://www.melon.com/song/detail.htm?songId=3536906',
#                '오오 오오 오오 걸었어 그냥 걸었어 니 생각이 나 또 걸었어 길잃은 어린아이처럼 갈 곳을 ...'),
#               ('지나오다',
#                '닐로(Nilo)',
#                'https://www.melon.com/song/detail.htm?songId=30699142',
#                '이별을 말하고 넌 괜찮은 거니 여전히 내 하루는 온통 네 생각에 뜬 눈으로 밤을 지새고 난...'),
#               ('Way Back Home',
#                '숀 (SHAUN)',
#                'https://www.melon.com/song/detail.htm?songId=31151836',
#                '멈춘 시간 속 잠든 너를 찾아가 아무리 막아도 결국 너의 곁인 걸 길고 긴 여행을 끝내 이...'),
#               ('You',
#                '멜로망스',
#                'https://www.melon.com/song/detail.htm?songId=30849733',
#                '어떻게 난 해야 해 니가 떠난다고 말하면 난 혼자 남겨지는 게 더 두려울 텐데 이유를 말해...'),
#               ('My Way',
#                '이수 (엠씨더맥스)',
#                'https://www.melon.com/song/detail.htm?songId=30721801',
#                '흐르는 물결이 내 발목에 감겨 나가면 깊은 곳에 숨겨둔 아픈 기억 모두 살아나고 어디에 기...'),
#               ('가을 안부',
#                '먼데이 키즈 (Monday Kiz)',
#                'https://www.melon.com/song/detail.htm?songId=30669593',
#                '어떠니 잘 지냈니 지난 여름 유난히도 힘에 겹더라 올핸 새벽녘엔 제법 쌀쌀한 바람이 어느덧...'),
#               ('FAKE LOVE',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=31085237',
#                '널 위해서라면 난 슬퍼도 기쁜 척 할 수가 있었어 널 위해서라면 난 아파도 강한 척 할 수...'),
#               ('봄날',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30244931',
#                '보고 싶다 이렇게 말하니까 더 보고 싶다 너희 사진을 보고 있어도 보고 싶다 너무 야속한 ...'),
#               ('열애중',
#                '벤',
#                'https://www.melon.com/song/detail.htm?songId=31062863',
#                '아직 이별 중인 나에겐 끝이 아닌 것만 같아서 다른 사랑 중인 너지만 나는 아직 너와 열애...'),
#               ('미안해',
#                '양다일',
#                'https://www.melon.com/song/detail.htm?songId=30809895',
#                '습관처럼 떠오르던 눈에 아른거리던 네 모습이 더는 그려지지 않아 거짓뿐이었던 너의 말과 너...'),
#               ('비행운',
#                '문문 (MoonMoon)',
#                'https://www.melon.com/song/detail.htm?songId=30086173',
#                '매일매일이 잿빛이더라구 팽이돌듯이 빙빙 돌더라구 어른이 라는 따분한 벌레들이 야금야금 꿈을...'),
#               ('그리워하다',
#                '비투비',
#                'https://www.melon.com/song/detail.htm?songId=30672529',
#                'My life is incomplete It s Missing you 오늘도 하루를 보내 ...'),
#               ('이 별',
#                '길구봉구',
#                'https://www.melon.com/song/detail.htm?songId=30637776',
#                '함께였었던 너 지금 어느 별에 있니 난 아직도 이별에 있어 흩어져가는 하늘에 나를 태워 보...'),
#               ('밤이 되니까',
#                '펀치 (Punch)',
#                'https://www.melon.com/song/detail.htm?songId=30659630',
#                '오늘도 난 술을 마셔 우울하니까 네가 또 생각나니까 침대 위에 놓인 전활 꺼 둬야만 해 내...'),
#               ('Beautiful',
#                'Wanna One (워너원)',
#                'https://www.melon.com/song/detail.htm?songId=30725482',
#                '바보같이 아쉬움 많은 노래가 하늘에 닿기를 눈물 속에 밤새운 내 기도가 마음에 닿기를 어렸...'),
#               ('밤 (Time for the moon night)',
#                '여자친구 (GFRIEND)',
#                'https://www.melon.com/song/detail.htm?songId=31052421',
#                '떨려오는 별빛 반짝이는데 넌 어디를 보고 있는지 금방이라도 사라질 것 같은데 불을 켜줘 심...'),
#               ('좋니',
#                '윤종신',
#                'https://www.melon.com/song/detail.htm?songId=30486509',
#                '이제 괜찮니 너무 힘들었잖아 우리 그 마무리가 고작 이별뿐인 건데 우린 참 어려웠어 잘 지...'),
#               ('하루도 그대를 사랑하지 않은 적이 없었다',
#                '임창정',
#                'https://www.melon.com/song/detail.htm?songId=31316695',
#                '맞이하고 보내준 수 많은 일 년 중 그대 내게 떠났던 그 해가 있었죠 어디에 있을까 잘 지...'),
#               ('소나기 (Feat. 10cm)',
#                '용준형',
#                'https://www.melon.com/song/detail.htm?songId=30970444',
#                '멋대로 날 찾아와서 모든 걸 다 적시고 내 마음도 짙어져 널 원할 때쯤에 이내 떠나 가버렸...'),
#               ('비도 오고 그래서 (Feat. 신용재)',
#                '헤이즈 (Heize)',
#                'https://www.melon.com/song/detail.htm?songId=30492279',
#                '비도 오고 그래서 네 생각이 났어 생각이 나서 그래서 그랬던거지 별 의미 없지 오늘은 오랜...'),
#               ('1도 없어',
#                'Apink (에이핑크)',
#                'https://www.melon.com/song/detail.htm?songId=31161280',
#                'I m so sick of lying You gotta know that 잘 지내 잘 지내...'),
#               ('Universe',
#                'EXO',
#                'https://www.melon.com/song/detail.htm?songId=30806536',
#                '마음과 반대로 아픈 말이 나와 너를 힘들게 했던 나도 내가 힘든 걸 다짐과 다르게 나아진 ...'),
#               ('all of my life',
#                '박원',
#                'https://www.melon.com/song/detail.htm?songId=30550388',
#                '너무 힘들어 삶에 치이고 되는 것도 없고 가족도 안 보이고 언제부턴가 나도 중요하지 않고 ...'),
#               ('넋두리',
#                '닐로(Nilo)',
#                'https://www.melon.com/song/detail.htm?songId=9642570',
#                '잘 지내니 잘 사는 것 같아 친구들에게서 네 소식을 들어 많은 날이 지나버렸지만 마주했던 ...'),
#               ('봄여름가을겨울 (Still Life)',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=34845949',
#                '이듬해 질 녘 꽃 피는 봄 한여름 밤의 꿈 가을 타 겨울 내릴 눈 1년 네 번 또다시 봄 ...'),
#               ('사랑은 늘 도망가',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=34061322',
#                '눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만 떨었지...'),
#               ('정이라고 하자 (Feat. 10CM)',
#                'BIG Naughty (서동현)',
#                'https://www.melon.com/song/detail.htm?songId=34927767',
#                'Back to the day 갓 10대가 됐을 때 그때 내가 널 보지 못했다면 어땠을까 해...'),
#               ('LOVE me',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34875621',
#                'Hey girl, Where you at? (Where you at?) 대체 어디서 뭐 하...'),
#               ('다시 만날 수 있을까',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008524',
#                '너를 위해 해 줄 것이 하나 없어서 보낼 수밖에 없었고 네가 없이 사는 법을 알지 못해서 ...'),
#               ('INVU',
#                '태연 (TAEYEON)',
#                'https://www.melon.com/song/detail.htm?songId=34626109',
#                'Falling in love 너에겐 난 Option 시작부터 다른 너와 나 깨지는 Hear...'),
#               ('신호등',
#                '이무진',
#                'https://www.melon.com/song/detail.htm?songId=33480898',
#                '이제야 목적지를 정했지만 가려한 날 막아서네 난 갈 길이 먼데 새빨간 얼굴로 화를 냈던 친...'),
#               ('듣고 싶을까',
#                'MSG워너비(M.O.M)',
#                'https://www.melon.com/song/detail.htm?songId=34701627',
#                '우리 함께 듣던 그 노랠 듣고 싶을까 듣고 나서 잠시 날 생각은 할까 아주 혹시라도 넌 내...'),
#               ('아버지',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008527',
#                '하얀 머리 뽑아 달라며 한 개 백 원이라던 그 시절 다 지나가고 이젠 흰 눈만 남았네 그렇...'),
#               ('A bientot',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008528',
#                'A bientot A bientot 이 밤이 지나면 괜찮아질 수 있을까 쓰린 내 맘이 회복...'),
#               ('인생찬가',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008534',
#                '꿈처럼 지나간 시간 나는 무얼 찾고 싶었나 지도도 없이 걸어온 삶을 후회하진 않으리 떠난 ...'),
#               ('사랑역',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008529',
#                '돌고 돌아 사랑역 다시 한번 내렸네 아픔만 두고 떠나가는 저 기차는 말이 없는데 이리 갈까...'),
#               ('회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)',
#                'sokodomo',
#                'https://www.melon.com/song/detail.htm?songId=34256568',
#                '내가 슬플 때마다 이 노래가 찾아와 세상이 둥근 것처럼 우린 동글동글 인생은 회전목마 우린...'),
#               ('드라마',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=34481680',
#                '나도 한때는 그이의 손을 잡고 내가 온 세상 주인공이 된 듯 꽃송이의 꽃잎 하나하나까지 모...'),
#               ('리무진 (Feat. MINO) (Prod. GRAY)',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34298499',
#                '까만 리무진 보며 꿈을 키웠지 언젠가는 나도 저걸 갖게 될 거야 커다란 리무진에서 내가 내...'),
#               ('내 손을 잡아',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=3414749',
#                '느낌이 오잖아 떨리고 있잖아 언제까지 눈치만 볼 거니 네 맘을 말해봐 딴청 피우지 말란 말...'),
#               ('아무래도 난',
#                '주시크 (Joosiq)',
#                'https://www.melon.com/song/detail.htm?songId=34817660',
#                '아무렇지 않게 내 하루가 또 지나갈 쯤에 문득 네가 없다는 게 익숙해진 내가 낯설어지곤 해...'),
#               ('스물다섯, 스물하나',
#                '자우림',
#                'https://www.melon.com/song/detail.htm?songId=4276080',
#                '바람에 날려 꽃이 지는 계절엔 아직도 너의 손을 잡은 듯 그런 듯 해 그때는 아직 꽃이 아...'),
#               ('바라만 본다',
#                'MSG워너비(M.O.M)',
#                'https://www.melon.com/song/detail.htm?songId=33625988',
#                '내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁을 지켜...'),
#               ('눈이 오잖아(Feat.헤이즈)',
#                '이무진',
#                'https://www.melon.com/song/detail.htm?songId=34360855',
#                '한 달 좀 덜 된 기억들 주머니에 넣은 채 걷고 있어 몇 시간을 혹시 몰라 네가 좋아했던 ...'),
#               ('Counting Stars (Feat. Beenzino)',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=34398735',
#                'Counting stars 밤하늘에 펄 Better than your LV Your LV ...'),
#               ('호랑수월가',
#                '탑현',
#                'https://www.melon.com/song/detail.htm?songId=34535898',
#                '흐르는 저 하늘을 물어 채는 범처럼 태산에 날아들어 숨어드는 새처럼 동산을 뛰고 뛰어가는 ...'),
#               ('고백',
#                '멜로망스',
#                'https://www.melon.com/song/detail.htm?songId=33868791',
#                '달이 차고 내 마음도 차고 이대로 담아 두기엔 너무 안타까워 너를 향해 가는데 달은 내게 ...'),
#               ('사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)',
#                '호미들',
#                'https://www.melon.com/song/detail.htm?songId=33359725',
#                '울려댔어 사이렌 텅 빈 길거리엔 도망치다 흘린 칼자루와 피가 흥건해 우리 그때 어릴땐 뭘 ...'),
#               ('봄날',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30244931',
#                '보고 싶다 이렇게 말하니까 더 보고 싶다 너희 사진을 보고 있어도 보고 싶다 너무 야속한 ...'),
#               ('미친 것처럼',
#                'V.O.S',
#                'https://www.melon.com/song/detail.htm?songId=35126568',
#                '너는 참 못됐다 나 없이도 잘 지내더라 언제쯤 나도 널 잊을 수 있을까 눈을 감아도 눈물이...'),
#               ('헤픈 우연',
#                '헤이즈 (Heize)',
#                'https://www.melon.com/song/detail.htm?songId=33503722',
#                '처음이라기엔 너무 길을 이미 다 아는 듯이 우연히라기엔 모두 다 정해진 듯이 우연히 눈을 ...'),
#               ('어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#                'AKMU (악뮤)',
#                'https://www.melon.com/song/detail.htm?songId=32061975',
#                '일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 ...'),
#               ('Shadow',
#                '세븐틴',
#                'https://www.melon.com/song/detail.htm?songId=35223433',
#                '저 멀리 뜨거운 해 떠오르지 않길 원했어 (Oh wuh) 빛의 반대편 그늘진 모든 게 싫어...'),
#               ('너, 너 (N번째 연애 X 휘인 (Whee In))',
#                '휘인 (Whee In)',
#                'https://www.melon.com/song/detail.htm?songId=34632789',
#                '하루 종일 집에 누워서 전화기만 보고 있잖아 내 머릿속은 네 생각들로만 짜여져 있어 날 찾...'),
#               ('서랍',
#                '10CM',
#                'https://www.melon.com/song/detail.htm?songId=34373632',
#                '어린 햇살 아래서 뛰어놀곤 했었던 가쁜 숨결 굽이진 골목 지나 길을 따라가보면 같은 기억 ...'),
#               ('어제처럼',
#                '폴킴',
#                'https://www.melon.com/song/detail.htm?songId=34701996',
#                'Trust the warmth inside Can you feel my love alive...'),
#               ('신호등',
#                '이무진',
#                'https://www.melon.com/song/detail.htm?songId=33480898',
#                '이제야 목적지를 정했지만 가려한 날 막아서네 난 갈 길이 먼데 새빨간 얼굴로 화를 냈던 친...'),
#               ('내 손을 잡아',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=3414749',
#                '느낌이 오잖아 떨리고 있잖아 언제까지 눈치만 볼 거니 네 맘을 말해봐 딴청 피우지 말란 말...'),
#               ('바라만 본다',
#                'MSG워너비(M.O.M)',
#                'https://www.melon.com/song/detail.htm?songId=33625988',
#                '내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁을 지켜...'),
#               ('잠이 오질 않네요',
#                '장범준',
#                'https://www.melon.com/song/detail.htm?songId=33013877',
#                '당신은 날 설레게 만들어 조용한 내 마음 자꾸만 춤추게 해 얼마나 얼마나 날 떨리게 하는지...'),
#               ('헤픈 우연',
#                '헤이즈 (Heize)',
#                'https://www.melon.com/song/detail.htm?songId=33503722',
#                '처음이라기엔 너무 길을 이미 다 아는 듯이 우연히라기엔 모두 다 정해진 듯이 우연히 눈을 ...'),
#               ('Lovesick Girls',
#                'BLACKPINK',
#                'https://www.melon.com/song/detail.htm?songId=32961718',
#                '영원한 밤 창문 없는 방에 우릴 가둔 love What can we say 매번 아파도 외...'),
#               ('운전만해 (We Ride)',
#                '브레이브걸스',
#                'https://www.melon.com/song/detail.htm?songId=32860397',
#                '넌 운전만 해 계속 운전만 해 왜 이리 된 걸까 우리 사이가 갑자기 어색해졌단 걸 왜 달라...'),
#               ('에잇(Prod.&Feat. SUGA of BTS)',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=32578498',
#                'So are you happy now Finally happy now are you 뭐 그...'),
#               ('어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#                'AKMU (악뮤)',
#                'https://www.melon.com/song/detail.htm?songId=32061975',
#                '일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 ...'),
#               ('흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#                '장범준',
#                'https://www.melon.com/song/detail.htm?songId=32003395',
#                '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 스쳐지나간건가 뒤돌아보지만 그냥 사람들만 보이...'),
#               ('그날에 나는 맘이 편했을까',
#                '이예준',
#                'https://www.melon.com/song/detail.htm?songId=33107649',
#                '늘 똑같은 일로 싸우다 지친 우리 끝날 때 됐나 봐 너답지 않던 모습 더는 지켜보기 힘들었...'),
#               ('Life Goes On',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=33077234',
#                '어느 날 세상이 멈췄어 아무런 예고도 하나 없이 봄은 기다림을 몰라서 눈치 없이 와버렸어 ...'),
#               ('사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)',
#                '호미들',
#                'https://www.melon.com/song/detail.htm?songId=33359725',
#                '울려댔어 사이렌 텅 빈 길거리엔 도망치다 흘린 칼자루와 피가 흥건해 우리 그때 어릴땐 뭘 ...'),
#               ('봄날',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30244931',
#                '보고 싶다 이렇게 말하니까 더 보고 싶다 너희 사진을 보고 있어도 보고 싶다 너무 야속한 ...'),
#               ('멜로디',
#                'ASH ISLAND',
#                'https://www.melon.com/song/detail.htm?songId=33315511',
#                '어딘가 들어본 듯한 이 Melody 떠올라 작은 기억들이 My memories 날 담은 소...'),
#               ('추억은 만남보다 이별에 남아',
#                '정동하',
#                'https://www.melon.com/song/detail.htm?songId=33248758',
#                '아득한 시간 속에 아직 우리 사랑이 남아있을까 멀어지던 그날의 너를 따라 걸어도 텅 빈 거...'),
#               ('사실 나는 (Feat.전건호)',
#                '경서예지',
#                'https://www.melon.com/song/detail.htm?songId=32525311',
#                '그땐 우리 둘 다 철없이 어리기만 했나 봐 태어나 처음 설레는 너를 만나서 세상에 부러울 ...'),
#               ('힘든 건 사랑이 아니다',
#                '임창정',
#                'https://www.melon.com/song/detail.htm?songId=32998018',
#                '내가 널 떠났어야 했는데 왜 떠나야 하는지도 아는데 어떤 아무 말도 아무것도 줄 게 없는 ...'),
#               ('어떻게 지내 (Prod. By VAN.C)',
#                '오반',
#                'https://www.melon.com/song/detail.htm?songId=32438894',
#                '어떻게 지내 식상한 말이 내 가사가 될 줄 몰랐어 얼마 안됐네 지나온 날이 다 알아도 그립...'),
#               ('같은 시간 속의 너',
#                '나얼',
#                'https://www.melon.com/song/detail.htm?songId=5576417',
#                '꼭 그러지 않아도 충분히 널 이해할 수 있어 다른 사람 곁에 서 있는 니 모습이 조금 어색...'),
#               ('이럴거면 그러지말지 (Feat. Young K)',
#                '백아연',
#                'https://www.melon.com/song/detail.htm?songId=5704397',
#                '궁금해서 잠이 안 와 그때 왜 그랬어 구차해도 묻고 싶어 그때 난 뭐였어 나나 나나 나나 ...'),
#               ('위잉위잉',
#                '혁오 (HYUKOH)',
#                'https://www.melon.com/song/detail.htm?songId=5385974',
#                '비틀비틀 걸어가는 나의 다리 오늘도 의미없는 또 하루가 흘러가죠 사랑도 끼리끼리 하는거라 ...'),
#               ('LOSER',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=5682700',
#                'LOSER 외톨이 센 척하는 겁쟁이 못된 양아치 거울 속에 넌 JUST A LOSER 외톨...'),
#               ('와리가리',
#                '혁오 (HYUKOH)',
#                'https://www.melon.com/song/detail.htm?songId=5713422',
#                '그런 슬픈 말을 하지 마요 아마 그럴 줄은 알았는데 이젠 좀 잔잔하다 했었는데 뒤도 돌아보...'),
#               ('다른 남자 말고 너',
#                '미쓰에이',
#                'https://www.melon.com/song/detail.htm?songId=5644636',
#                '다른 남자 말고 너 다른 남자 말고 너너 너 장난해 장난해 하는데 나는 절대로 장난이 아닌...'),
#               ('두사랑 (Feat. 매드클라운)',
#                '다비치',
#                'https://www.melon.com/song/detail.htm?songId=5628083',
#                '미쳤다고 하겠지 내 지금 사랑이 어떤 건지 듣는 사람들은 사랑이란 반드시 한 사람과 하는 ...'),
#               ('마음',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=5700639',
#                '툭 웃음이 터지면 그건 너 쿵 내려앉으면은 그건 너 축 머금고 있다면 그건 너 둥 울림이 ...'),
#               ('그 남잔 말야',
#                '엠씨더맥스 (M.C the MAX)',
#                'https://www.melon.com/song/detail.htm?songId=5668985',
#                '바람 부는 이런 날엔 넌 어디서 뭘 하는지 오늘 따라 오늘 따라 궁금해 너무 쉽게 잊혀 지...'),
#               ('목소리',
#                '노을',
#                'https://www.melon.com/song/detail.htm?songId=5536206',
#                '너무 보고 싶어서 가만히 너를 떠올려 보기도 했어 기억 속 네가 흐려진 만큼 잊혀진 거라 ...'),
#               ('사월의 눈',
#                '허각',
#                'https://www.melon.com/song/detail.htm?songId=5629186',
#                '어느새 그 차가웠던 긴 겨울에 하얀 눈도 스르륵 봄바람에 다 녹아내려요 다시 또 누군가를 ...'),
#               ('야생화',
#                '박효신',
#                'https://www.melon.com/song/detail.htm?songId=4543502',
#                '하얗게 피어난 얼음 꽃 하나가 달가운 바람에 얼굴을 내밀어 아무 말 못했던 이름도 몰랐던 ...'),
#               ('I (Feat. 버벌진트)',
#                '태연 (TAEYEON)',
#                'https://www.melon.com/song/detail.htm?songId=7877917',
#                '빛을 쏟는 Sky 그 아래 선 아이 I 꿈꾸듯이 Fly My Life is a Beauty...'),
#               ('IF YOU',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=5760115',
#                '그녀가 떠나가요 나는 아무것도 할 수 없어요 사랑이 떠나가요 나는 바보처럼 멍하니 서 있네...'),
#               ('우리 사랑하지 말아요',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=5807274',
#                '우리 사랑하지 말아요 아직은 잘 모르잖아요 사실 조금은 두려운 거야 그대 미안해요 우리 약...'),
#               ('또 운다 또',
#                '다비치',
#                'https://www.melon.com/song/detail.htm?songId=5555751',
#                '또 운다 또 울지 말라니까 내 말 좀 들어라 터진 눈물아 약한 마음아 상처 난 가슴아 나는...'),
#               ('LUV',
#                'Apink (에이핑크)',
#                'https://www.melon.com/song/detail.htm?songId=5473905',
#                '기억하나요 우리 함께 했던 시간 L O V E LUV 설레이나요 한 땐 모든 것이었던 L ...'),
#               ('바라보기',
#                '엠씨더맥스 (M.C the MAX)',
#                'https://www.melon.com/song/detail.htm?songId=5482064',
#                '마음이 알고 가 낯선 길인데도 니 숨결이 머문 자리는 너무 그립다 그립다 못해 아프다 누군...'),
#               ('광화문에서 (At Gwanghwamun)',
#                '규현 (KYUHYUN)',
#                'https://www.melon.com/song/detail.htm?songId=5458267',
#                '넌 어땠는지 아직 여름이 남아 왠지 난 조금 지쳤던 하루 광화문 가로수 은행잎 물들 때 그...'),
#               ('흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#                '장범준',
#                'https://www.melon.com/song/detail.htm?songId=32003395',
#                '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 스쳐지나간건가 뒤돌아보지만 그냥 사람들만 보이...'),
#               ('에잇(Prod.&Feat. SUGA of BTS)',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=32578498',
#                'So are you happy now Finally happy now are you 뭐 그...'),
#               ('늦은 밤 너의 집 앞 골목길에서',
#                '노을',
#                'https://www.melon.com/song/detail.htm?songId=32156286',
#                '오래되었어 그때 너의 웃음 너의 목소리 잊혀진거 같아 시간의 위로 그 말의 의미를 이젠 알...'),
#               ('어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#                'AKMU (악뮤)',
#                'https://www.melon.com/song/detail.htm?songId=32061975',
#                '일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 ...'),
#               ('처음처럼',
#                '엠씨더맥스 (M.C the MAX)',
#                'https://www.melon.com/song/detail.htm?songId=32486613',
#                '눈이 부시게 웃던 널 기억해 이제는 다시 볼 수 없게 됐지만 끝내 붙잡았던 기억들만 이 겨...'),
#               ('살짝 설렜어 (Nonstop)',
#                '오마이걸 (OH MY GIRL)',
#                'https://www.melon.com/song/detail.htm?songId=32559781',
#                'going nonstop 말도 안 되잖아 그치 yayayaya 우린 서로가 모르는 게 없는...'),
#               ('마리아 (Maria)',
#                '화사 (Hwa Sa)',
#                'https://www.melon.com/song/detail.htm?songId=32725013',
#                '욕을 하도 먹어 체했어 하도 서러워도 어쩌겠어 I do 모두들 미워하느라 애썼네 날 무너뜨...'),
#               ('어떻게 지내 (Prod. By VAN.C)',
#                '오반',
#                'https://www.melon.com/song/detail.htm?songId=32438894',
#                '어떻게 지내 식상한 말이 내 가사가 될 줄 몰랐어 얼마 안됐네 지나온 날이 다 알아도 그립...'),
#               ('다시 여기 바닷가',
#                '싹쓰리 (유두래곤, 린다G, 비룡)',
#                'https://www.melon.com/song/detail.htm?songId=32790516',
#                '예아 호우 예예예 싹쓰리 인더 하우스 커커몬 싹 쓰리 투 렛츠고 나 다시 또 설레어 이렇게...'),
#               ('안녕',
#                '폴킴',
#                'https://www.melon.com/song/detail.htm?songId=31984204',
#                '안녕 이라는 말을해 짧은 시간을 뒤로 한채로 여전히 아프겠지만 하룻밤 자고 나면 사라지는 ...'),
#               ('그때 그 아인',
#                '김필',
#                'https://www.melon.com/song/detail.htm?songId=32377231',
#                '길었던 하루 그림잔 아직도 아픔을 서성일까 말없이 기다려 보면 쓰러질 듯 내게 와 안기는데...'),
#               ('Love poem',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=32143487',
#                '누구를 위해 누군가 기도하고 있나 봐 숨죽여 쓴 사랑시가 낮게 들리는 듯해 너에게로 선명히...'),
#               ('우리 왜 헤어져야 해',
#                '신예영',
#                'https://www.melon.com/song/detail.htm?songId=32187544',
#                '이런 말 하기까지가 참 어려워서 그대를 보낼 준비가 되질 않아서 아프고 또 아파서 이젠 무...'),
#               ('봄날',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30244931',
#                '보고 싶다 이렇게 말하니까 더 보고 싶다 너희 사진을 보고 있어도 보고 싶다 너무 야속한 ...'),
#               ('Black Swan',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=32323969',
# ...
#                'Bubble pop Bubble pop 첨부터 끝까지 날 바꾸려 하지마 아니면 차라리 다른...'),
#               ('Black & White',
#                '지나',
#                'https://www.melon.com/song/detail.htm?songId=3111583',
#                'Black Black Black White Black Black Black White Bl...'),
#               ('instagram',
#                'DEAN',
#                'https://www.melon.com/song/detail.htm?songId=30806580',
#                '내일이 올 걸 아는데 난 핸드폰을 놓지 못해 잠은 올 생각이 없대 yeah 다시 인스타그램...'),
#               ('아무노래',
#                '지코 (ZICO)',
#                'https://www.melon.com/song/detail.htm?songId=32313543',
#                '왜들 그리 다운돼있어 뭐가 문제야 say something 분위기가 겁나 싸해 요새는 이런...'),
#               ('그런 남자',
#                'Bro',
#                'https://www.melon.com/song/detail.htm?songId=4535038',
#                '말하지 않아도 네맘 알아주고 달래주는 그런남자 너무 힘이들어서 지칠때 항상 네 편이 되어주...'),
#               ('SIGNAL',
#                'TWICE (트와이스)',
#                'https://www.melon.com/song/detail.htm?songId=30413326',
#                'Trying to let you know Sign을 보내 signal 보내 I must l...')],
#              '기쁨': [('이상형',
#                '버스커 버스커',
#                'https://www.melon.com/song/detail.htm?songId=3743293',
#                '헤이 브래드 완전 뷰리풀 걸 저기 데어 어디 웨어 헐 헐 이게 뭐야 이게 아 왜 좋자나 그...'),
#               ('한여름밤의 꿀',
#                'San E, 레이나 (Raina)',
#                'https://www.melon.com/song/detail.htm?songId=4681146',
#                '무더운 밤 잠은 오지 않고 이런저런 생각에 불러본 너 나올 줄 몰랐어 간지러운 바람 웃고 ...')],
#              '짜증': [('봄이 좋냐??',
#                '10CM',
#                'https://www.melon.com/song/detail.htm?songId=8124417',
#                '꽃이 언제 피는지 그딴 게 뭐가 중요한데 날씨가 언제 풀리는지 그딴 거 알면 뭐 할 건데 ...'),
#               ('Ah Yeah',
#                'EXID',
#                'https://www.melon.com/song/detail.htm?songId=5660040',
#                '아예 아예 아예 아예 아예 아예 아예 아예 아예 아예 왜 이렇게 감을 못 잡는거야 왜 이 ...'),
#               ('I LUV IT',
#                '싸이 (PSY)',
#                'https://www.melon.com/song/detail.htm?songId=30403589',
#                '내 나이 사십 babe 울 엄마 귀한 자식 babe 직업은 댄스 가수 babe 15년째 딴...')],
#              '깨달음': [('Forever (Prod. By GRAY)',
#                'BewhY (비와이)',
#                'https://www.melon.com/song/detail.htm?songId=8252408',
#                '래퍼 딱지를 떼는 중 이젠 MC로 폼 잡고 걸어가고 싶어 예술가의 길로 확실히 단단해져버린...'),
#               ('The Time Goes On',
#                'BewhY (비와이)',
#                'https://www.melon.com/song/detail.htm?songId=5620266',
#                '시간이 끊임없이 흐르지 그에 따라 난 내 발을 구르지 죽을힘으로 달려도 죽을지언정 절대로 ...'),
#               ('So Cool (쏘쿨)',
#                '씨스타',
#                'https://www.melon.com/song/detail.htm?songId=3521672',
#                'Are you Ready Sistar and Brave Sound We re No.1 Th...'),
#               ('METEOR',
#                '창모 (CHANGMO)',
#                'https://www.melon.com/song/detail.htm?songId=32224272',
#                'Yeah ha Yeah ha Yeah ha Yeah ha Yeah ha Yeah ha Ye...'),
#               ('METEOR',
#                '창모 (CHANGMO)',
#                'https://www.melon.com/song/detail.htm?songId=32224272',
#                'Yeah ha Yeah ha Yeah ha Yeah ha Yeah ha Yeah ha Ye...'),
#               ('초록빛',
#                '폴킴',
#                'https://www.melon.com/song/detail.htm?songId=31565593',
#                '버려진 담배꽁초 흔들리는 처량함 휘청거리는 휜 맥주 뚜껑에 난 또 감상에 젖어 오늘 밤은 ...'),
#               ('SOLO',
#                '제니 (JENNIE)',
#                'https://www.melon.com/song/detail.htm?songId=31417871',
#                '천진난만 청순가련 새침한 척 이젠 지쳐 나 귀찮아 매일 뭐 해 어디야 밥은 잘 자 Baby...'),
#               ('Love Shot',
#                'EXO',
#                'https://www.melon.com/song/detail.htm?songId=31492319',
#                '차갑도록 서롤 겨눈 채 날이 선 듯 그 목소리엔 숨막히는 것만 가득해 Oh oh oh oh...')],
#              '힘듦/지침': [('또 하루 (Feat. 개코)',
#                '개리',
#                'https://www.melon.com/song/detail.htm?songId=7999021',
#                '나 홀로 외로워진 밤에 모든 게 버거워진 밤에 I love you I need you Yo...'),
#               ('만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)',
#                '베이식 (Basick)',
#                'https://www.melon.com/song/detail.htm?songId=34298496',
#                '만남은 쉽고 이별은 어려워 눈빛에 베일 듯 우린 날카로워 마침표를 찍고 난 조금 더 멀리 ...'),
#               ('여행',
#                '볼빨간사춘기',
#                'https://www.melon.com/song/detail.htm?songId=31093710',
#                '저 오늘 떠나요 공항으로 핸드폰 꺼 놔요 제발 날 찾진 말아줘 시끄럽게 소리를 질러도 어쩔...'),
#               ('너나 해 (Egotistic)',
#                '마마무 (Mamamoo)',
#                'https://www.melon.com/song/detail.htm?songId=31189241',
#                '난 너의 위성 네 주윌 맴돌지 그렇다고 네가 태양은 아니니 너의 멋대로 중심이 돼 제멋대로...'),
#               ('만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)',
#                '베이식 (Basick)',
#                'https://www.melon.com/song/detail.htm?songId=34298496',
#                '만남은 쉽고 이별은 어려워 눈빛에 베일 듯 우린 날카로워 마침표를 찍고 난 조금 더 멀리 ...'),
#               ('취기를 빌려 (취향저격 그녀 X 산들)',
#                '산들',
#                'https://www.melon.com/song/detail.htm?songId=32794652',
#                '언제부턴가 불쑥 내 습관이 돼버린 너 혹시나 이런 맘이 어쩌면 부담일까 널 주저했어 언제부...'),
#               ('취기를 빌려 (취향저격 그녀 X 산들)',
#                '산들',
#                'https://www.melon.com/song/detail.htm?songId=32794652',
#                '언제부턴가 불쑥 내 습관이 돼버린 너 혹시나 이런 맘이 어쩌면 부담일까 널 주저했어 언제부...'),
#               ('Summer Hate (Feat. 비)',
#                '지코 (ZICO)',
#                'https://www.melon.com/song/detail.htm?songId=32734372',
#                'Good morning 하마터면 달 뜰 때까지 쿨쿨쿨 잠잘 뻔 택배 아저씨 초인종 소리에 ...'),
#               ('조금 취했어 (Prod. 2soo)',
#                '임재현',
#                'https://www.melon.com/song/detail.htm?songId=32059630',
#                '내가 망가지면 니가 나를 볼까 봐 나를 혹시나 걱정해줄까 봐 몸에 안 좋은 거 하러 왔어 ...'),
#               ('자니 (Feat. Dynamic Duo)',
#                '프라이머리',
#                'https://www.melon.com/song/detail.htm?songId=3726617',
#                '일 끝나서 친구들과 한잔 내일은 노는 토요일이니깐 일 얘기 사는 얘기 재미난 얘기 시간가는...'),
#               ('자니 (Feat. Dynamic Duo)',
#                '프라이머리',
#                'https://www.melon.com/song/detail.htm?songId=3726617',
#                '일 끝나서 친구들과 한잔 내일은 노는 토요일이니깐 일 얘기 사는 얘기 재미난 얘기 시간가는...'),
#               ('미친연애 (Bad Girl) (Feat. E-Sens Of 슈프림팀)',
#                '범키',
#                'https://www.melon.com/song/detail.htm?songId=4130922',
#                'Yeah let me tell you about this one girl i know Sh...'),
#               ('U & I',
#                '에일리(Ailee)',
#                'https://www.melon.com/song/detail.htm?songId=4171462',
#                'Wait a minute Wait a minute 말 잘라 미안한데 왜 이러니 왜 이러니 ...'),
#               ('에라 모르겠다',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=30147445',
#                "No I don't wanna go too fast Cuz nothing really la..."),
#               ('시차 (We Are) (Feat. 로꼬 & GRAY)',
#                '우원재',
#                'https://www.melon.com/song/detail.htm?songId=30613202',
#                '밤새 모니터에 튀긴 침이 마르기도 전에 강의실로 아 참 교수님이 문신 땜에 긴 팔 입고 오...'),
#               ('나만, 봄',
#                '볼빨간사춘기',
#                'https://www.melon.com/song/detail.htm?songId=31709523',
#                '안돼 그만둬 거기까지 해 더 다가가면 너 정신 못 차려 안돼 그만해 꽃은 넣어둬 그냥 좀 ...')],
#              '비장함': [('TOMBOY',
#                '(여자)아이들',
#                'https://www.melon.com/song/detail.htm?songId=34754292',
#                'Look at you 넌 못 감당해 날 Ya took off hook 기분은 Coke li...'),
#               ('FEARLESS',
#                'LE SSERAFIM (르세라핌)',
#                'https://www.melon.com/song/detail.htm?songId=35009233',
#                'Bam ba ba ba ba bam ba ba ba ba bam Ba ba ba ba ba...'),
#               ('STAY',
#                'The Kid LAROI, Justin Bieber',
#                'https://www.melon.com/song/detail.htm?songId=33658563',
#                'I do the same thing I told you that I never would ...'),
#               ("That's Hilarious",
#                'Charlie Puth',
#                'https://www.melon.com/song/detail.htm?songId=34864406',
#                'Verse 1: Look how all tables, Look how all the tab...'),
#               ('Butter',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=33507137',
#                'Smooth like butter Like a criminal undercover Gon ...'),
#               ('Bad Habits',
#                'Ed Sheeran',
#                'https://www.melon.com/song/detail.htm?songId=33623210',
#                'Every time you come around you know I can t say no...'),
#               ('TOMBOY',
#                '(여자)아이들',
#                'https://www.melon.com/song/detail.htm?songId=34754292',
#                'Look at you 넌 못 감당해 날 Ya took off hook 기분은 Coke li...'),
#               ('FEARLESS',
#                'LE SSERAFIM (르세라핌)',
#                'https://www.melon.com/song/detail.htm?songId=35009233',
#                'Bam ba ba ba ba bam ba ba ba ba bam Ba ba ba ba ba...'),
#               ('STAY',
#                'The Kid LAROI, Justin Bieber',
#                'https://www.melon.com/song/detail.htm?songId=33658563',
#                'I do the same thing I told you that I never would ...'),
#               ("That's Hilarious",
#                'Charlie Puth',
#                'https://www.melon.com/song/detail.htm?songId=34864406',
#                'Verse 1: Look how all tables, Look how all the tab...'),
#               ('Butter',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=33507137',
#                'Smooth like butter Like a criminal undercover Gon ...'),
#               ('Bad Habits',
#                'Ed Sheeran',
#                'https://www.melon.com/song/detail.htm?songId=33623210',
#                'Every time you come around you know I can t say no...'),
#               ('Butter',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=33507137',
#                'Smooth like butter Like a criminal undercover Gon ...'),
#               ('On The Ground',
#                '로제 (ROSÉ)',
#                'https://www.melon.com/song/detail.htm?songId=33346446',
#                "My life's been magic seems fantastic I used to hav..."),
#               ('뱅뱅뱅 (BANG BANG BANG)',
#                'BIGBANG (빅뱅)',
#                'https://www.melon.com/song/detail.htm?songId=5719286',
#                '난 깨어나 까만 밤과 함께 다 들어와 담엔 누구 차례 한 치 앞도 볼 수 없는 막장 게릴라...'),
#               ('How You Like That',
#                'BLACKPINK',
#                'https://www.melon.com/song/detail.htm?songId=32720013',
#                '보란 듯이 무너졌어 바닥을 뚫고 저 지하까지 옷 끝자락 잡겠다고 저 높이 두 손을 뻗어봐도...'),
#               ('돌덩이',
#                '하현우 (국카스텐)',
#                'https://www.melon.com/song/detail.htm?songId=32361098',
#                'Hit me harder Make me strong 그저 정해진 대로 따르라고 그게 현명하...'),
#               ('연결고리#힙합',
#                'BOBBY',
#                'https://www.melon.com/song/detail.htm?songId=4854588',
#                'Yeah It s that remix right here My name is Bobby I...')],
#              '고마움': [('사랑해요 그대를',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008533',
#                '너무나 고마운 사람 너무나 따뜻한 사람 한 번도 잊어본 적 없는 내 마음속에 그 사람 나 ...'),
#               ('사랑해요 그대를',
#                '임영웅',
#                'https://www.melon.com/song/detail.htm?songId=35008533',
#                '너무나 고마운 사람 너무나 따뜻한 사람 한 번도 잊어본 적 없는 내 마음속에 그 사람 나 ...')],
#              '화남/분노': [('Step Back',
#                'GOT the beat',
#                'https://www.melon.com/song/detail.htm?songId=34494149',
#                'You must step back 어델 어델 봐 너 감히 누구라고 날 제껴 이쯤에서 물러나...'),
#               ('Savage',
#                'aespa',
#                'https://www.melon.com/song/detail.htm?songId=34041584',
#                "Oh my gosh! Don't you know I m a Savage? I m a Kil..."),
#               ('Hate You',
#                '2NE1',
#                'https://www.melon.com/song/detail.htm?songId=3488750',
#                '넌 정말 재수없어 널 만날 이유 없어 너 같은 남잔 이세상에 깔렸어 재 재 재 재수없어 단...'),
#               ('Step Back',
#                'GOT the beat',
#                'https://www.melon.com/song/detail.htm?songId=34494149',
#                'You must step back 어델 어델 봐 너 감히 누구라고 날 제껴 이쯤에서 물러나...'),
#               ('Savage',
#                'aespa',
#                'https://www.melon.com/song/detail.htm?songId=34041584',
#                "Oh my gosh! Don't you know I m a Savage? I m a Kil..."),
#               ('화 (Feat. 진실 Of Mad Soul Child) (Fire)',
#                '매드클라운',
#                'https://www.melon.com/song/detail.htm?songId=5531227',
#                '화 (Feat. 진실 Of Mad Soul Child) (Fire) Trouble Trou...'),
#               ('손대지마',
#                '에일리(Ailee)',
#                'https://www.melon.com/song/detail.htm?songId=5394265',
#                '날 사랑한다는 그 흔해빠진 거짓말 반복되는 싸움 gotta go I say good bye...'),
#               ('니가 뭔데 (Who You?)',
#                'G-DRAGON',
#                'https://www.melon.com/song/detail.htm?songId=4226211',
#                'Baby I love you 이렇게 말하지만 내 마음은 왠지 하나도 좋지 않아 I want...')],
#              '당황/난처': [('문득',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=33448767',
#                '배가 고파서 밥을 차렸는데 문득 네가 앉아서 내 앞에서 웃어서 멍을 때리다가 정신 차렸는데...'),
#               ('삐삐',
#                '아이유',
#                'https://www.melon.com/song/detail.htm?songId=31346009',
#                'Hi there 인사해 호들갑 없이 시작해요 서론 없이 스킨십은 사양할게요 back off...'),
#               ('문득',
#                "BE'O (비오)",
#                'https://www.melon.com/song/detail.htm?songId=33448767',
#                '배가 고파서 밥을 차렸는데 문득 네가 앉아서 내 앞에서 웃어서 멍을 때리다가 정신 차렸는데...'),
#               ('Dolphin',
#                '오마이걸 (OH MY GIRL)',
#                'https://www.melon.com/song/detail.htm?songId=32559782',
#                'oh my god 타이밍이 참 얄미워 오늘 같은 날 마주쳐 이게 뭐야 머리는 엉망인 데다 ...'),
#               ('Dolphin',
#                '오마이걸 (OH MY GIRL)',
#                'https://www.melon.com/song/detail.htm?songId=32559782',
#                'oh my god 타이밍이 참 얄미워 오늘 같은 날 마주쳐 이게 뭐야 머리는 엉망인 데다 ...'),
#               ('씨스루 (Feat. Zion.T, 개코 Of 다이나믹듀오)',
#                '프라이머리',
#                'https://www.melon.com/song/detail.htm?songId=3948908',
#                'Party time 아는 사람 없네 지루해 앉아있기만 해 바텐더 뭘 마셔야 해 그래 그걸로...'),
#               ('노래방에서',
#                '장범준',
#                'https://www.melon.com/song/detail.htm?songId=31684636',
#                '나는 사랑이 어떻게 이뤄지는 지 연구 했지 여러가지 상황의 수를 계산 해 봤지 그땐 내가 ...')],
#              '불안/걱정': [('주지마',
#                '로꼬, 화사 (Hwa Sa)',
#                'https://www.melon.com/song/detail.htm?songId=31035061',
#                '위험해 아슬아슬해 간신히 끈을 잡았는데 넌 가위질을 하려고 해 너의 호의는 필요 없어 인내...'),
#               ('낙하 (with 아이유)',
#                'AKMU (악뮤)',
#                'https://www.melon.com/song/detail.htm?songId=33725775',
#                '말했잖아 언젠가 이런 날이 온다면 난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야, 봐...'),
#               ('위아래',
#                'EXID',
#                'https://www.melon.com/song/detail.htm?songId=4840271',
#                '위 아래 위 위 아래 위 아래 위 위 아래 위 아래 위 위 아래 UP 위 아래 위 위 아래...'),
#               ('으르렁 (Growl)',
#                'EXO',
#                'https://www.melon.com/song/detail.htm?songId=4193337',
#                'Yo Okay 나 혹시 몰라 경고하는데 잘 들어 지금 위험해 So Dangerous 자꾸 ...'),
#               ('이 노래가 클럽에서 나온다면',
#                '우디 (Woody)',
#                'https://www.melon.com/song/detail.htm?songId=31576009',
#                '이 노래가 클럽에서 나온다면 네가 이 음악에 춤출 수 있을까요 이 노래가 클럽에서 나온다면...')],
#              '감동/감탄': [('DNA',
#                '방탄소년단',
#                'https://www.melon.com/song/detail.htm?songId=30637982',
#                '첫눈에 널 알아보게 됐어 서롤 불러왔던 것처럼 내 혈관 속 DNA가 말해줘 내가 찾아 헤매...'),
#               ('인연',
#                '윤민수(바이브), 신용재 (2F)',
#                'https://www.melon.com/song/detail.htm?songId=4582959',
#                '인연이라고 하죠 거부 할 수가 없죠 이 사랑이 녹슬지 않도록 늘 닦아 비출게요 약속해요 이...'),
#               ('HER',
#                '블락비 (Block B)',
#                'https://www.melon.com/song/detail.htm?songId=4764928',
#                'Jesus 무슨 말이 필요해 모두 널 작품이라고 불러 Just a little bit of...')],
#              '흐뭇함(귀여움/예쁨)': [('BAAAM (Feat. Muzie Of UV)',
#                '다이나믹 듀오',
#                'https://www.melon.com/song/detail.htm?songId=4160246',
#                '오전에 보낸 문자는 메아리가 없어 하루 종일 내 기분은 맥아리가 없어 친구들에겐 밀고 당기...')]})
