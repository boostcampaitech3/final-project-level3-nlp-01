# %%
from crawler import MusicLyricsCrawler

# %%
mc = MusicLyricsCrawler()
mc.crawl()
# Out:
# Initialize Drive
# Start parsing
# title :  50 , singer :  50 , lytic :  50
# data 수: 50
# Save to csv
#                                      title                        singer  \
# 0                                   TOMBOY                       (여자)아이들
# 1                                LOVE DIVE                     IVE (아이브)
# 2                     봄여름가을겨울 (Still Life)                  BIGBANG (빅뱅)
# 3                                   사랑인가 봐                          멜로망스
# 4                     정이라고 하자 (Feat. 10CM)             BIG Naughty (서동현)
# 5                                   나의 X에게                            경서
# 6                           Feel My Rhythm             Red Velvet (레드벨벳)
# 7                                  LOVE me                     BE'O (비오)
# 8                                     취중고백                    김민석 (멜로망스)
# 9                     GANADARA (Feat. 아이유)                           박재범
# ...

# %%
import pandas as pd

# %%
lyrics = pd.read_csv('Lyrics top100.csv')
print(len(lyrics))
lyrics.head()
# Out:
#     Unnamed: 0                                   title  \
# 0            0                                  TOMBOY
# 1            1                               LOVE DIVE
# 2            2                    봄여름가을겨울 (Still Life)
# 3            3                                  사랑인가 봐
# 4            4                    정이라고 하자 (Feat. 10CM)
# 5            5                                  나의 X에게
# 6            6                          Feel My Rhythm
# 7            7                                 LOVE me
# 8            8                                    취중고백
# 9            9                    GANADARA (Feat. 아이유)
# 10          10                                FEARLESS
# 11          11                               사랑은 늘 도망가
# 12          12                                    ZOOM
# 13          13                                    INVU
# 14          14                                     신호등
# 15          15                                  듣고 싶을까
# ...
