# %%
from crawler import MusicLyricsCrawler

# %%
mc = MusicLyricsCrawler()
mc.crawl(3)
# Out:
# Initialize Drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.8/site-packages/selenium/webdriver/common/service.py:71, in Service.start(self)
#      <a href='file:///opt/conda/lib/python3.8/site-packages/selenium/webdriver/common/service.py?line=69'>70</a>     cmd.extend(self.command_line_args())
# ---> <a href='file:///opt/conda/lib/python3.8/site-packages/selenium/webdriver/common/service.py?line=70'>71</a>     self.process = subprocess.Popen(cmd, env=self.env,
#      <a href='file:///opt/conda/lib/python3.8/site-packages/selenium/webdriver/common/service.py?line=71'>72</a>                                     close_fds=system() != 'Windows',
#      <a href='file:///opt/conda/lib/python3.8/site-packages/selenium/webdriver/common/service.py?line=72'>73</a>                                     stdout=self.log_file,
# ...
